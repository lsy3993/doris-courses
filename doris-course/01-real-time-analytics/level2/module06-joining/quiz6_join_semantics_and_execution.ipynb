# %% [markdown]
# <div style="max-width:100%;box-sizing:border-box;overflow:visible;border-top:4px solid #0f766e;padding:32px 0 20px;margin:0 0 24px">
#   <div style="display:block;color:#0f766e;font-size:13px;line-height:1.8;font-weight:700;letter-spacing:0.8px;text-transform:uppercase;margin:0 0 8px">QUIZ 06 · REAL-TIME ANALYTICS WITH APACHE DORIS</div>
#   <div style="color:#17212b;font-size:30px;line-height:1.3;font-weight:750;margin:0 0 10px">Join Semantics and Execution</div>
#   <p style="color:#475569;font-size:15px;line-height:1.7;max-width:900px;margin:0">Apply Module 6 concepts to small, independent business scenarios. Read the explanation and revise any answer before continuing.</p>
#   <span style="display:inline-block;border:1px solid #99f6e4;border-radius:4px;background:#f0fdfa;color:#115e59;padding:6px 10px;margin-top:14px;font-size:12px">6 questions · Single choice · Approximately 8 minutes</span>
# </div>

# %% [markdown]
# ## What this quiz assesses
#
# - Return only missing relationships.
# - Predict metric multiplication.
# - Define NULL matching deliberately.
# - Separate hash keys from residual conditions.
# - Read planned data movement.
# - Interpret a Runtime Filter plan.
#
# These are independent scenarios, not copies of Lab results. No Docker, Doris, S3, Kafka, or completed Lab is required. Use a Jupyter environment with ipywidgets and PyYAML installed. All question data is local.

# %% [markdown]
# ### Initialize the Quiz
#
# Run the initialization cell once. It locates the course package, reads this Module's quiz definition, and creates the interactive quiz object. Run it again whenever you restart the Jupyter kernel.

# %%
from pathlib import Path
import sys

COURSE_ROOT = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "doris_course").is_dir()
)
if str(COURSE_ROOT) not in sys.path:
    sys.path.insert(0, str(COURSE_ROOT))

from doris_course.quiz import CourseQuiz

QUIZ_PATH = COURSE_ROOT / "level2/module06-joining/quiz6_join_semantics_and_execution.yaml"
quiz = CourseQuiz.from_yaml(QUIZ_PATH)

# %% [markdown]
# ## Start the knowledge check
#
# Run the next cell. Select an option and choose **Submit answer** to read its explanation. Use **Previous question** to go back. You can change any selection; submit the revised answer before continuing. Unsubmitted selections are preserved as drafts. **View results** shows your score and missed questions. From there, **Previous question** returns to Question 6 and **Try again** clears the attempt.

# %%
quiz.show();
# Out:
# HTML(value='\n<style>\n.doris-quiz-shell {\n  border: 1px solid #dbe4e8;\n  border-top: 4px solid #0f766e;\n  …
# VBox(_dom_classes=('doris-quiz-root',))
