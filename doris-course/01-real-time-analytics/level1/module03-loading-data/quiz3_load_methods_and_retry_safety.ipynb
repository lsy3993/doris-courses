# %% [markdown]
# <div style="max-width:100%;box-sizing:border-box;overflow:visible;border-top:4px solid #0f766e;padding:32px 0 20px;margin:0 0 24px">
#   <div style="display:block;color:#0f766e;font-size:13px;line-height:1.8;font-weight:700;letter-spacing:0.8px;text-transform:uppercase;margin:0 0 8px">QUIZ 03 · REAL-TIME ANALYTICS WITH APACHE DORIS</div>
#   <div style="color:#17212b;font-size:30px;line-height:1.3;font-weight:750;margin:0 0 10px">Load Methods and Retry Safety</div>
#   <p style="color:#475569;font-size:15px;line-height:1.7;max-width:900px;margin:0">Check whether you can match workload contracts to Doris load methods, interpret quality evidence, and choose the correct persistence and retry model.</p>
#   <span style="display:inline-block;border:1px solid #99f6e4;border-radius:4px;background:#f0fdfa;color:#115e59;padding:6px 10px;margin-top:14px;font-size:12px">5 questions · Single choice · Approximately 5 minutes</span>
# </div>

# %% [markdown]
# ## What this quiz assesses
#
# Each question covers a different Module 3 learning objective:
#
# - selecting Group Commit and its acknowledgement mode for a high-frequency small-write workload;
# - interpreting filtered rows and a rejected Stream Load transaction;
# - using a Stream Load label to retry one uncertain batch safely;
# - separating temporary S3 TVF access from persistence through `INSERT INTO SELECT`;
# - mapping nested Kafka JSON and reasoning about committed offset progress in a Routine Load job.
#
# This is a self-check, not a graded Lab. It does not require Docker, a running Doris sandbox, Kafka, or S3 credentials. Submit one answer at a time. After each submission, read the explanation before moving to the next question.

# %% [markdown]
# ### Initialize the Quiz
#
# Run the initialization cell once. It locates the course package, reads this Module's quiz definition, and creates the interactive quiz object. Run it again whenever you restart the Jupyter kernel.

# %%
from pathlib import Path
import sys

COURSE_ROOT = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "doris_course").is_dir()
)
if str(COURSE_ROOT) not in sys.path:
    sys.path.insert(0, str(COURSE_ROOT))

from doris_course.quiz import CourseQuiz

QUIZ_PATH = COURSE_ROOT / "level1/module03-loading-data/quiz3_load_methods_and_retry_safety.yaml"
quiz = CourseQuiz.from_yaml(QUIZ_PATH)

# %% [markdown]
# ## Start the knowledge check
#
# Run the next cell to display Question 1. Select one option and choose **Submit answer**. The interface explains the result before enabling the next question. Use **Previous question** to revisit an earlier answer; you can change a submitted answer and submit it again, while an unsubmitted selection is preserved as a draft. At the end, the interface reports the total score and reviews only the questions that were answered incorrectly. **Previous question** returns to Question 5, and **Try again** starts a fresh attempt.

# %%
quiz.show();
# Out:
# HTML(value='\n<style>\n.doris-quiz-shell {\n  border: 1px solid #dbe4e8;\n  border-top: 4px solid #0f766e;\n  …
# VBox(_dom_classes=('doris-quiz-root',))
